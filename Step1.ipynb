# %%
import pandas as pd
import os
#os library gives a way of using operating system dependent functionalities. Such as manipulating folder and file paths. We use this library to get all the Excel file names, including their paths.

# %%
df1 = pd.ExcelFile("data.xlsx")

# %%
list_of_sheets = df1.sheet_names

# %%
list_of_sheets
# Out:
# ['Info',
#  'Cycle_67_1_1',
#  'Statis_67_1_1',
#  'Detail_67_1_1',
#  'Detail_67_1_1_1',
#  'Detail_67_1_1_2',
#  'Detail_67_1_1_3',
#  'Detail_67_1_1_4',
#  'Detail_67_1_1_5',
#  'Detail_67_1_1_6',
#  'DetailVol_67_1_1',
#  'DetailVol_67_1_1_1',
#  'DetailVol_67_1_1_2',
#  'DetailVol_67_1_1_3',
#  'DetailVol_67_1_1_4',
#  'DetailVol_67_1_1_5',
#  'DetailVol_67_1_1_6',
#  'DetailTemp_67_1_1',
#  'DetailTemp_67_1_1_1',
#  'DetailTemp_67_1_1_2']

# %%
import re

# %%
final_data = [x  for x in list_of_sheets if re.search('Detail_67_1_1',x,re.IGNORECASE)]

# %%
final_data
# Out:
# ['Detail_67_1_1',
#  'Detail_67_1_1_1',
#  'Detail_67_1_1_2',
#  'Detail_67_1_1_3',
#  'Detail_67_1_1_4',
#  'Detail_67_1_1_5',
#  'Detail_67_1_1_6']

# %%
df_final=pd.read_excel('data.xlsx',sheet_name=['Detail_67_1_1','Detail_67_1_1_1','Detail_67_1_1_2','Detail_67_1_1_3','Detail_67_1_1_4','Detail_67_1_1_5','Detail_67_1_1_6'])

# %%
df_final
# Out:
# {'Detail_67_1_1':        Record Index     Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  \
#  0                 1       Rest       1      1     1      0.0      3.5900
#  1                 2       Rest       1      1     1      0.0      3.5900
#  2                 3       Rest       1      1     1      0.0      3.5900
#  3                 4       Rest       1      1     1      0.0      3.5900
#  4                 5       Rest       1      1     1      0.0      3.5900
#  ...             ...        ...     ...    ...   ...      ...         ...
#  65530         65531  CCCV_DChg      19      4    17   -870.1      3.6573
#  65531         65532  CCCV_DChg      19      4    17   -870.1      3.6579
#  65532         65533  CCCV_DChg      19      4    17   -870.1      3.6573
#  65533         65534  CCCV_DChg      19      4    17   -870.1      3.6573
#  65534         65535  CCCV_DChg      19      4    17   -870.1      3.6573
#
#         CapaCity(mAh)  Energy(mWh) Relative Time(h:min:s.ms)  \
# ...

# %%
Task1 = pd.concat(df_final[frame] for frame in df_final.keys())

# %%
Task1
# Out:
#        Record Index Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  \
# 0                 1   Rest       1      1     1      0.0      3.5900
# 1                 2   Rest       1      1     1      0.0      3.5900
# 2                 3   Rest       1      1     1      0.0      3.5900
# 3                 4   Rest       1      1     1      0.0      3.5900
# 4                 5   Rest       1      1     1      0.0      3.5900
# ...             ...    ...     ...    ...   ...      ...         ...
# 23466        458630   Rest     108     21    83      0.0      3.5856
# 23467        458631   Rest     108     21    83      0.0      3.5853
# 23468        458632   Rest     108     21    83      0.0      3.5853
# 23469        458633   Rest     108     21    83      0.0      3.5856
# 23470        458634   Rest     108     21    83      0.0      3.5856
#
#        CapaCity(mAh)  Energy(mWh) Relative Time(h:min:s.ms)  \
# 0                0.0          0.0               0:00:00.000
# ...

# %%
Task1
# Out:
#        Record Index Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  \
# 0                 1   Rest       1      1     1      0.0      3.5900
# 1                 2   Rest       1      1     1      0.0      3.5900
# 2                 3   Rest       1      1     1      0.0      3.5900
# 3                 4   Rest       1      1     1      0.0      3.5900
# 4                 5   Rest       1      1     1      0.0      3.5900
# ...             ...    ...     ...    ...   ...      ...         ...
# 23466        458630   Rest     108     21    83      0.0      3.5856
# 23467        458631   Rest     108     21    83      0.0      3.5853
# 23468        458632   Rest     108     21    83      0.0      3.5853
# 23469        458633   Rest     108     21    83      0.0      3.5856
# 23470        458634   Rest     108     21    83      0.0      3.5856
#
#        CapaCity(mAh)  Energy(mWh) Relative Time(h:min:s.ms)  \
# 0                0.0          0.0               0:00:00.000
# ...

# %%
Task1 = pd.concat(df_final,sort=False)

# %%
Task1
# Out:
#                        Record Index Status  JumpTo  Cycle  Step  Cur(mA)  \
# Detail_67_1_1   0                 1   Rest       1      1     1      0.0
#                 1                 2   Rest       1      1     1      0.0
#                 2                 3   Rest       1      1     1      0.0
#                 3                 4   Rest       1      1     1      0.0
#                 4                 5   Rest       1      1     1      0.0
# ...                             ...    ...     ...    ...   ...      ...
# Detail_67_1_1_6 23466        458630   Rest     108     21    83      0.0
#                 23467        458631   Rest     108     21    83      0.0
#                 23468        458632   Rest     108     21    83      0.0
#                 23469        458633   Rest     108     21    83      0.0
#                 23470        458634   Rest     108     21    83      0.0
#
#                        Voltage(V)  CapaCity(mAh)  Energy(mWh)  \
# ...

# %%
Task1 = pd.concat(df_final[frame] for frame in df_final.keys())

# %%
Task1
# Out:
#        Record Index Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  \
# 0                 1   Rest       1      1     1      0.0      3.5900
# 1                 2   Rest       1      1     1      0.0      3.5900
# 2                 3   Rest       1      1     1      0.0      3.5900
# 3                 4   Rest       1      1     1      0.0      3.5900
# 4                 5   Rest       1      1     1      0.0      3.5900
# ...             ...    ...     ...    ...   ...      ...         ...
# 23466        458630   Rest     108     21    83      0.0      3.5856
# 23467        458631   Rest     108     21    83      0.0      3.5853
# 23468        458632   Rest     108     21    83      0.0      3.5853
# 23469        458633   Rest     108     21    83      0.0      3.5856
# 23470        458634   Rest     108     21    83      0.0      3.5856
#
#        CapaCity(mAh)  Energy(mWh) Relative Time(h:min:s.ms)  \
# 0                0.0          0.0               0:00:00.000
# ...

# %%
Task1.set_index("Record Index",inplace=True)

# %%
Task1
# Out:
#              Status  JumpTo  Cycle  Step  Cur(mA)  Voltage(V)  CapaCity(mAh)  \
# Record Index
# 1              Rest       1      1     1      0.0      3.5900            0.0
# 2              Rest       1      1     1      0.0      3.5900            0.0
# 3              Rest       1      1     1      0.0      3.5900            0.0
# 4              Rest       1      1     1      0.0      3.5900            0.0
# 5              Rest       1      1     1      0.0      3.5900            0.0
# ...             ...     ...    ...   ...      ...         ...            ...
# 458630         Rest     108     21    83      0.0      3.5856            0.0
# 458631         Rest     108     21    83      0.0      3.5853            0.0
# 458632         Rest     108     21    83      0.0      3.5853            0.0
# 458633         Rest     108     21    83      0.0      3.5856            0.0
# 458634         Rest     108     21    83      0.0      3.5856            0.0
#
# ...

# %%
Task1.to_csv("D:\\1.intern\detail.csv")

# %% [markdown]
# # 2.Combine all the data in sheets named like "DetailVol_67_" only, among the two data files provided, and save into `'detailVol.csv'`

# %%
list_of_sheets
# Out:
# ['Info',
#  'Cycle_67_1_1',
#  'Statis_67_1_1',
#  'Detail_67_1_1',
#  'Detail_67_1_1_1',
#  'Detail_67_1_1_2',
#  'Detail_67_1_1_3',
#  'Detail_67_1_1_4',
#  'Detail_67_1_1_5',
#  'Detail_67_1_1_6',
#  'DetailVol_67_1_1',
#  'DetailVol_67_1_1_1',
#  'DetailVol_67_1_1_2',
#  'DetailVol_67_1_1_3',
#  'DetailVol_67_1_1_4',
#  'DetailVol_67_1_1_5',
#  'DetailVol_67_1_1_6',
#  'DetailTemp_67_1_1',
#  'DetailTemp_67_1_1_1',
#  'DetailTemp_67_1_1_2']

# %%
Col_data = [x  for x in list_of_sheets if re.search('DetailVol_67_1_1',x,re.IGNORECASE)]

# %%
Col_data
# Out:
# ['DetailVol_67_1_1',
#  'DetailVol_67_1_1_1',
#  'DetailVol_67_1_1_2',
#  'DetailVol_67_1_1_3',
#  'DetailVol_67_1_1_4',
#  'DetailVol_67_1_1_5',
#  'DetailVol_67_1_1_6']

# %%
df_final1=pd.read_excel('data.xlsx',sheet_name=['DetailVol_67_1_1','DetailVol_67_1_1_1','DetailVol_67_1_1_2','DetailVol_67_1_1_3','DetailVol_67_1_1_4','DetailVol_67_1_1_5','DetailVol_67_1_1_6'])

# %%
df_final1
# Out:
# {'DetailVol_67_1_1':        Record ID  Step Name Relative Time(h:min:s.ms)            Realtime  \
#  0              1       Rest               0:00:00.000 2020-10-10 20:03:39
#  1              2       Rest               0:00:01.000 2020-10-10 20:03:40
#  2              3       Rest               0:00:02.000 2020-10-10 20:03:41
#  3              4       Rest               0:00:03.000 2020-10-10 20:03:42
#  4              5       Rest               0:00:04.000 2020-10-10 20:03:43
#  ...          ...        ...                       ...                 ...
#  65530      65531  CCCV_DChg               1:44:03.000 2020-10-11 14:15:30
#  65531      65532  CCCV_DChg               1:44:04.000 2020-10-11 14:15:31
#  65532      65533  CCCV_DChg               1:44:05.000 2020-10-11 14:15:32
#  65533      65534  CCCV_DChg               1:44:06.000 2020-10-11 14:15:33
#  65534      65535  CCCV_DChg               1:44:07.000 2020-10-11 14:15:34
#
# ...

# %%
Task2 = pd.concat(df_final1[frame] for frame in df_final1.keys())

# %%
Task2
# Out:
#        Record ID Step Name Relative Time(h:min:s.ms)            Realtime  \
# 0              1      Rest               0:00:00.000 2020-10-10 20:03:39
# 1              2      Rest               0:00:01.000 2020-10-10 20:03:40
# 2              3      Rest               0:00:02.000 2020-10-10 20:03:41
# 3              4      Rest               0:00:03.000 2020-10-10 20:03:42
# 4              5      Rest               0:00:04.000 2020-10-10 20:03:43
# ...          ...       ...                       ...                 ...
# 23466     458630      Rest               0:09:56.000 2020-10-16 03:25:35
# 23467     458631      Rest               0:09:57.000 2020-10-16 03:25:36
# 23468     458632      Rest               0:09:58.000 2020-10-16 03:25:37
# 23469     458633      Rest               0:09:59.000 2020-10-16 03:25:38
# 23470     458634      Rest               0:10:00.000 2020-10-16 03:25:39
#
#        Auxiliary channel TU1 U(V)  Gap of Voltage
# ...

# %%
Task2.set_index('Record ID',inplace=True)

# %%
Task2
# Out:
#           Step Name Relative Time(h:min:s.ms)            Realtime  \
# Record ID
# 1              Rest               0:00:00.000 2020-10-10 20:03:39
# 2              Rest               0:00:01.000 2020-10-10 20:03:40
# 3              Rest               0:00:02.000 2020-10-10 20:03:41
# 4              Rest               0:00:03.000 2020-10-10 20:03:42
# 5              Rest               0:00:04.000 2020-10-10 20:03:43
# ...             ...                       ...                 ...
# 458630         Rest               0:09:56.000 2020-10-16 03:25:35
# 458631         Rest               0:09:57.000 2020-10-16 03:25:36
# 458632         Rest               0:09:58.000 2020-10-16 03:25:37
# 458633         Rest               0:09:59.000 2020-10-16 03:25:38
# 458634         Rest               0:10:00.000 2020-10-16 03:25:39
#
#            Auxiliary channel TU1 U(V)  Gap of Voltage
# Record ID
# 1                             -0.0013               0
# ...

# %%
Task2.to_csv("D:\\1.intern\detailVol.csv")

# %% [markdown]
# # 3. Combine all the data in sheets named like "DetailTemp_67_" only, among the two data files provided, and save into `'detailTemp.csv'`

# %%
list_of_sheets
# Out:
# ['Info',
#  'Cycle_67_1_1',
#  'Statis_67_1_1',
#  'Detail_67_1_1',
#  'Detail_67_1_1_1',
#  'Detail_67_1_1_2',
#  'Detail_67_1_1_3',
#  'Detail_67_1_1_4',
#  'Detail_67_1_1_5',
#  'Detail_67_1_1_6',
#  'DetailVol_67_1_1',
#  'DetailVol_67_1_1_1',
#  'DetailVol_67_1_1_2',
#  'DetailVol_67_1_1_3',
#  'DetailVol_67_1_1_4',
#  'DetailVol_67_1_1_5',
#  'DetailVol_67_1_1_6',
#  'DetailTemp_67_1_1',
#  'DetailTemp_67_1_1_1',
#  'DetailTemp_67_1_1_2']

# %%
import re
final_data2 = [x  for x in list_of_sheets if re.search('DetailTemp_67_1_1',x,re.IGNORECASE)]

# %%
final_data2
# Out:
# ['DetailTemp_67_1_1', 'DetailTemp_67_1_1_1', 'DetailTemp_67_1_1_2']

# %%
data2 = pd.ExcelFile("data_1.xlsx")

# %%
data2

# %%
list_of_sheets1 = data2.sheet_names

# %%
list_of_sheets1
# Out:
# ['DetailTemp_67_1_1_3',
#  'DetailTemp_67_1_1_4',
#  'DetailTemp_67_1_1_5',
#  'DetailTemp_67_1_1_6']

# %%
data1_temp = final_data2 + list_of_sheets1

# %%
data1_temp
# Out:
# ['DetailTemp_67_1_1',
#  'DetailTemp_67_1_1_1',
#  'DetailTemp_67_1_1_2',
#  'DetailTemp_67_1_1_3',
#  'DetailTemp_67_1_1_4',
#  'DetailTemp_67_1_1_5',
#  'DetailTemp_67_1_1_6']

# %%
path = os.getcwd()
files = os.listdir(path)
files
# Out:
# ['.ipynb_checkpoints',
#  'Assign',
#  'Assignment.md',
#  'Data',
#  'data.xlsx',
#  'Data.zip',
#  'data_1.xlsx',
#  'detail.csv',
#  'detailVol.csv',
#  'input.csv',
#  'output.csv',
#  'output1.csv',
#  'output11.csv',
#  'Step1.ipynb',
#  'Step2.ipynb',
#  'sudhpandas.ipynb',
#  'Task',
#  'Task.zip',
#  'Untitled.ipynb',
#  'Untitled3.ipynb']

# %%
files_xls = [f for f in files if f[-4:] == 'xlsx']
files_xls
# Out:
# ['data.xlsx', 'data_1.xlsx']

# %%
df_temp1= pd.read_excel('data.xlsx',sheet_name = ['DetailTemp_67_1_1', 'DetailTemp_67_1_1_1', 'DetailTemp_67_1_1_2'])

# %%
df_temp1
# Out:
# {'DetailTemp_67_1_1':        Record ID  Step Name Relative Time(h:min:s.ms)            Realtime  \
#  0              1       Rest               0:00:00.000 2020-10-10 20:03:39
#  1              2       Rest               0:00:01.000 2020-10-10 20:03:40
#  2              3       Rest               0:00:02.000 2020-10-10 20:03:41
#  3              4       Rest               0:00:03.000 2020-10-10 20:03:42
#  4              5       Rest               0:00:04.000 2020-10-10 20:03:43
#  ...          ...        ...                       ...                 ...
#  65530      65531  CCCV_DChg               1:44:03.000 2020-10-11 14:15:30
#  65531      65532  CCCV_DChg               1:44:04.000 2020-10-11 14:15:31
#  65532      65533  CCCV_DChg               1:44:05.000 2020-10-11 14:15:32
#  65533      65534  CCCV_DChg               1:44:06.000 2020-10-11 14:15:33
#  65534      65535  CCCV_DChg               1:44:07.000 2020-10-11 14:15:34
#
# ...

# %%
T1 = pd.concat(df_temp1[frame] for frame in df_temp1.keys())

# %%
T1.set_index('Record ID',inplace=True)

# %%
T1
# Out:
#            Step Name Relative Time(h:min:s.ms)            Realtime  \
# Record ID
# 1               Rest               0:00:00.000 2020-10-10 20:03:39
# 2               Rest               0:00:01.000 2020-10-10 20:03:40
# 3               Rest               0:00:02.000 2020-10-10 20:03:41
# 4               Rest               0:00:03.000 2020-10-10 20:03:42
# 5               Rest               0:00:04.000 2020-10-10 20:03:43
# ...              ...                       ...                 ...
# 196601     CCCV_DChg               0:04:05.000 2020-10-13 02:39:27
# 196602     CCCV_DChg               0:04:06.000 2020-10-13 02:39:28
# 196603     CCCV_DChg               0:04:07.000 2020-10-13 02:39:29
# 196604     CCCV_DChg               0:04:08.000 2020-10-13 02:39:30
# 196605     CCCV_DChg               0:04:09.000 2020-10-13 02:39:31
#
#            Auxiliary channel TU1 T(°C)  Gap of Temperature
# Record ID
# 1                                 27.7                   0
# ...

# %%
df_temp2 = pd.read_excel('data_1.xlsx',sheet_name = ['DetailTemp_67_1_1_3','DetailTemp_67_1_1_4','DetailTemp_67_1_1_5','DetailTemp_67_1_1_6'])

# %%
df_temp2
# Out:
# {'DetailTemp_67_1_1_3':        Record ID  Step Name Relative Time(h:min:s.ms)            Realtime  \
#  0         196606  CCCV_DChg               0:04:10.000 2020-10-13 02:39:32
#  1         196607  CCCV_DChg               0:04:11.000 2020-10-13 02:39:33
#  2         196608  CCCV_DChg               0:04:12.000 2020-10-13 02:39:34
#  3         196609  CCCV_DChg               0:04:13.000 2020-10-13 02:39:35
#  4         196610  CCCV_DChg               0:04:14.000 2020-10-13 02:39:36
#  ...          ...        ...                       ...                 ...
#  65530     262136   CCCV_Chg               2:41:26.000 2020-10-13 20:51:29
#  65531     262137   CCCV_Chg               2:41:27.000 2020-10-13 20:51:30
#  65532     262138   CCCV_Chg               2:41:28.000 2020-10-13 20:51:31
#  65533     262139   CCCV_Chg               2:41:29.000 2020-10-13 20:51:32
#  65534     262140   CCCV_Chg               2:41:30.000 2020-10-13 20:51:33
#
# ...

# %%
T2 = pd.concat(df_temp2[frame] for frame in df_temp2.keys())

# %%
T2
# Out:
#        Record ID  Step Name Relative Time(h:min:s.ms)            Realtime  \
# 0         196606  CCCV_DChg               0:04:10.000 2020-10-13 02:39:32
# 1         196607  CCCV_DChg               0:04:11.000 2020-10-13 02:39:33
# 2         196608  CCCV_DChg               0:04:12.000 2020-10-13 02:39:34
# 3         196609  CCCV_DChg               0:04:13.000 2020-10-13 02:39:35
# 4         196610  CCCV_DChg               0:04:14.000 2020-10-13 02:39:36
# ...          ...        ...                       ...                 ...
# 23466     458630       Rest               0:09:56.000 2020-10-16 03:25:35
# 23467     458631       Rest               0:09:57.000 2020-10-16 03:25:36
# 23468     458632       Rest               0:09:58.000 2020-10-16 03:25:37
# 23469     458633       Rest               0:09:59.000 2020-10-16 03:25:38
# 23470     458634       Rest               0:10:00.000 2020-10-16 03:25:39
#
#        Auxiliary channel TU1 T(°C)  Gap of Temperature
# ...

# %%
T2.set_index('Record ID',inplace=True)

# %%
T2
# Out:
#            Step Name Relative Time(h:min:s.ms)            Realtime  \
# Record ID
# 196606     CCCV_DChg               0:04:10.000 2020-10-13 02:39:32
# 196607     CCCV_DChg               0:04:11.000 2020-10-13 02:39:33
# 196608     CCCV_DChg               0:04:12.000 2020-10-13 02:39:34
# 196609     CCCV_DChg               0:04:13.000 2020-10-13 02:39:35
# 196610     CCCV_DChg               0:04:14.000 2020-10-13 02:39:36
# ...              ...                       ...                 ...
# 458630          Rest               0:09:56.000 2020-10-16 03:25:35
# 458631          Rest               0:09:57.000 2020-10-16 03:25:36
# 458632          Rest               0:09:58.000 2020-10-16 03:25:37
# 458633          Rest               0:09:59.000 2020-10-16 03:25:38
# 458634          Rest               0:10:00.000 2020-10-16 03:25:39
#
#            Auxiliary channel TU1 T(°C)  Gap of Temperature
# Record ID
# 196606                            28.3                   0
# ...

# %%
Task3 = T1.append(T2)

# %%
Task3
# Out:
#           Step Name Relative Time(h:min:s.ms)            Realtime  \
# Record ID
# 1              Rest               0:00:00.000 2020-10-10 20:03:39
# 2              Rest               0:00:01.000 2020-10-10 20:03:40
# 3              Rest               0:00:02.000 2020-10-10 20:03:41
# 4              Rest               0:00:03.000 2020-10-10 20:03:42
# 5              Rest               0:00:04.000 2020-10-10 20:03:43
# ...             ...                       ...                 ...
# 458630         Rest               0:09:56.000 2020-10-16 03:25:35
# 458631         Rest               0:09:57.000 2020-10-16 03:25:36
# 458632         Rest               0:09:58.000 2020-10-16 03:25:37
# 458633         Rest               0:09:59.000 2020-10-16 03:25:38
# 458634         Rest               0:10:00.000 2020-10-16 03:25:39
#
#            Auxiliary channel TU1 T(°C)  Gap of Temperature
# Record ID
# 1                                 27.7                   0
# ...

# %%
Task3.to_csv("D:\\1.intern\detailTemp.csv")
